# %% [markdown]
# # White-box Performances

# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from typing import Union, List, Dict, Tuple

# %%
def get_attack_config(attack_type):
    """Returns the specific configuration for different attack types."""

    if attack_type == "fgsm":
        return {
            "param_name": "eps",
            "param_display": "Epsilon",
            "param_format": "{:.3f}",
            "norm_type": "l2",
            "norm_display": "L2",
        }
    elif attack_type == "cw":
        return {
            "param_name": "c",
            "param_display": "C Parameter",
            "param_format": "{:.3f}",
            "norm_type": "l2",
            "norm_display": "L2",
        }
    elif attack_type == "jsma":
        return {
            "param_name": "theta",
            "param_display": "Theta",
            "param_format": "{:.3f}",
            "norm_type": "l2",
            "norm_display": "L2",
        }
    else:
        raise ValueError(f"Unsupported attack type: {attack_type}")


def extract_data(file_path, encoding_name, attack_config):
    """Extract data from CSV file based on attack configuration."""
    data_points = []

    try:
        df = pd.read_csv(file_path)
        param_name = attack_config["param_name"]
        norm_type = attack_config["norm_type"]

        for _, row in df.iterrows():
            # Extract parameter from attack_params
            try:
                param_dict = eval(row["attack_params"])
                param_value = param_dict.get(param_name, None)
            except:
                param_value = None

            # Create data point
            data_point = {
                "encoding": encoding_name,
                "param_value": param_value,
                "accuracy": row["accuracy"],
                f"pct_change_{norm_type}": row[f"pct_change_{norm_type}"],
            }

            data_points.append(data_point)

    except Exception as e:
        print(f"Error processing {file_path}: {e}")

    return data_points


def estimate_param_for_target_pct_change(
    df: pd.DataFrame,
    target_pct_change: float,
    param_col: str = "param_value",
    pct_change_col: str = "pct_change_linf",
    encoding_col: str = None,
    encoding_value: str = None,
    interpolation_method: str = "linear",
) -> tuple[float, bool]:
    """
    Estimate the parameter value that would produce a specific percentage change.
    If the target is outside the available range, it clamps to the nearest value
    and returns a flag.
    """

    if encoding_col is not None and encoding_value is not None:
        df_filtered = df[df[encoding_col] == encoding_value].copy()
    else:
        df_filtered = df.copy()

    df_filtered = df_filtered.sort_values(by=param_col)
    param_values = df_filtered[param_col].values
    pct_changes = df_filtered[pct_change_col].values

    was_clamped = False #

    if target_pct_change < pct_changes.min():
        print(
            f"Warning: Target {target_pct_change}% is below the available range "
            f"[{pct_changes.min():.4f}%, {pct_changes.max():.4f}%]. Clamping to min."
        )
        # Find the parameter that corresponds to the minimum pct_change
        estimated_param = param_values[np.argmin(pct_changes)]
        was_clamped = True
        return estimated_param, was_clamped

    elif target_pct_change > pct_changes.max():
        print(
            f"Warning: Target {target_pct_change}% is above the available range "
            f"[{pct_changes.min():.4f}%, {pct_changes.max():.4f}%]. Clamping to max."
        )
        # Find the parameter that corresponds to the maximum pct_change
        estimated_param = param_values[np.argmax(pct_changes)]
        was_clamped = True
        return estimated_param, was_clamped

    # If we are within the range, proceed with interpolation as before
    lower_idx = None
    for i in range(len(pct_changes) - 1):
        if pct_changes[i] <= target_pct_change <= pct_changes[i + 1]:
            lower_idx = i
            break

    if lower_idx is None: # Should not happen with the checks above, but as a fallback
        lower_idx = len(pct_changes) - 2


    lower_param = param_values[lower_idx]
    upper_param = param_values[lower_idx + 1]
    lower_pct = pct_changes[lower_idx]
    upper_pct = pct_changes[lower_idx + 1]

    if interpolation_method == "linear":
        estimated_param = lower_param + (target_pct_change - lower_pct) * (
            upper_param - lower_param
        ) / (upper_pct - lower_pct)
    elif interpolation_method == "log":
        if ( lower_param <= 0 or lower_pct <= 0 or upper_param <= 0 or upper_pct <= 0 or target_pct_change <= 0):
            raise ValueError("Log interpolation requires positive values")
        log_lower_param = np.log10(lower_param)
        log_upper_param = np.log10(upper_param)
        log_lower_pct = np.log10(lower_pct)
        log_upper_pct = np.log10(upper_pct)
        log_target = np.log10(target_pct_change)
        log_estimated_param = log_lower_param + (log_target - log_lower_pct) * (
            log_upper_param - log_lower_param
        ) / (log_upper_pct - log_lower_pct)
        estimated_param = 10**log_estimated_param
    else:
        raise ValueError("Method must be 'linear' or 'log'")

    return estimated_param, was_clamped


def estimate_accuracy_for_param(
    df: pd.DataFrame,
    param_value: float,
    param_col: str = "param_value",
    accuracy_col: str = "accuracy",
    encoding_col: str = None,
    encoding_value: str = None,
    interpolation_method: str = "linear",
) -> float:
    """
    Estimate the accuracy for a specific parameter value using interpolation.

    Args:
        df: DataFrame containing parameter values and corresponding accuracy values
        param_value: The parameter value to find the accuracy for
        param_col: Column name for the parameter values
        accuracy_col: Column name for the accuracy values
        encoding_col: Optional column name for encoding/dataset type
        encoding_value: Optional specific encoding value to filter by
        method: Interpolation method ('linear' or 'log')

    Returns:
        Estimated accuracy at the specified parameter value
    """
    if encoding_col is not None and encoding_value is not None:
        df_filtered = df[df[encoding_col] == encoding_value].copy()
    else:
        df_filtered = df.copy()

    df_filtered = df_filtered.sort_values(by=param_col)

    param_values = df_filtered[param_col].values
    accuracy_values = df_filtered[accuracy_col].values

    if param_value < param_values.min() or param_value > param_values.max():
        print(
            f"Warning: Parameter value {param_value} is outside the available range "
            f"[{param_values.min():.4f}, {param_values.max():.4f}]. Extrapolating."
        )

    lower_idx = None
    for i in range(len(param_values) - 1):
        if param_values[i] <= param_value <= param_values[i + 1]:
            lower_idx = i
            break

    if lower_idx is None:
        if param_value < param_values[0]:
            lower_idx = 0
        else:
            lower_idx = len(param_values) - 2

    # Get the bracketing points
    lower_param = param_values[lower_idx]
    upper_param = param_values[lower_idx + 1]
    lower_acc = accuracy_values[lower_idx]
    upper_acc = accuracy_values[lower_idx + 1]

    if interpolation_method == "linear":
        estimated_accuracy = lower_acc + (param_value - lower_param) * (
            upper_acc - lower_acc
        ) / (upper_param - lower_param)
    elif interpolation_method == "log":
        if lower_param <= 0 or upper_param <= 0 or param_value <= 0:
            raise ValueError("Log interpolation requires positive parameter values")

        if lower_acc <= 0 or upper_acc <= 0:
            print("Warning: Accuracy values contain zeros. Using linear interpolation.")
            estimated_accuracy = lower_acc + (param_value - lower_param) * (
                upper_acc - lower_acc
            ) / (upper_param - lower_param)
        else:
            log_lower_param = np.log10(lower_param)
            log_upper_param = np.log10(upper_param)
            log_lower_acc = np.log10(lower_acc)
            log_upper_acc = np.log10(upper_acc)
            log_param = np.log10(param_value)

            log_estimated_acc = log_lower_acc + (log_param - log_lower_param) * (
                log_upper_acc - log_lower_acc
            ) / (log_upper_param - log_lower_param)

            estimated_accuracy = 10**log_estimated_acc

    else:
        raise ValueError("Method must be 'linear' or 'log'")

    return estimated_accuracy

def find_accuracy_at_target_pct_change(
    results_df: pd.DataFrame,
    target_pct_change: float,
    attack_config: dict,
    encoding: str,
    interpolation_method: str = "linear",
    verbose: bool = False,
) -> dict:
    """
    Finds the parameter for the target pct change, gets the accuracy,
    and now also tracks if the parameter was clamped.
    """
    norm_type = attack_config["norm_type"]
    param_name = attack_config["param_name"]
    param_format = attack_config.get("param_format", "{:.4f}")

    param_value, was_clamped = estimate_param_for_target_pct_change(
        results_df,
        target_pct_change=target_pct_change,
        param_col="param_value",
        pct_change_col=f"pct_change_{norm_type}",
        encoding_col="encoding",
        encoding_value=encoding,
        interpolation_method=interpolation_method,
    )

    accuracy = estimate_accuracy_for_param(
        results_df,
        param_value=param_value,
        param_col="param_value",
        accuracy_col="accuracy",
        encoding_col="encoding",
        encoding_value=encoding,
        interpolation_method=interpolation_method,
    )

    if verbose:
        print(
            f"\nFor {encoding} encoding at {target_pct_change}% change in {norm_type} norm:"
        )
        print(f"  {param_name} = {param_format.format(param_value)}")
        print(f"  Estimated accuracy: {accuracy:.4f}")

    return {
        "encoding": encoding,
        "target_pct_change": target_pct_change,
        "param_value": param_value,
        "param_name": param_name,
        "accuracy": accuracy,
        "norm_type": norm_type,
        "was_clamped": was_clamped
    }


def analyze_at_threshold(
    attack_type: str,
    results_df: pd.DataFrame,
    thresholds: list = [3.0, 10.0, 20.0],
    encodings: list = None,
    training_mode: str = "baseline",
    create_table: bool = True,
    baseline_model_metrics: dict = None,
) -> pd.DataFrame:
    """
    Analyzes model performance and now adds a 'Notes' column to the
    summary table if clamping occurred.
    """
    attack_config = get_attack_config(attack_type)
    if encodings is None:
        encodings = results_df["encoding"].unique()

    all_results = []
    for threshold in thresholds:
        for encoding in encodings:
            result = find_accuracy_at_target_pct_change(
                results_df,
                target_pct_change=threshold,
                attack_config=attack_config,
                encoding=encoding,
                interpolation_method="log",
            )
            all_results.append(result)

    results_table = pd.DataFrame(all_results)

    results_table["residual"] = results_table.apply(
        lambda row: baseline_model_metrics[row["encoding"]]["accuracy"]
        - row["accuracy"],
        axis=1,
    )
    results_table["residual_pct_change"] = results_table.apply(
        lambda row: (
            (baseline_model_metrics[row["encoding"]]["accuracy"] - row["accuracy"])
            / baseline_model_metrics[row["encoding"]]["accuracy"]
        )
        * 100,
        axis=1,
    )

    if create_table:
        print(f"\n{'='*80}")
        print(f"SUMMARY TABLE FOR {attack_type.upper()} ATTACK ({training_mode})")
        print(f"{'='*80}")

        # Format the table for display
        display_table = results_table.copy()

        display_table["param_value"] = display_table.apply(
            lambda row: attack_config["param_format"].format(row["param_value"]), axis=1
        )
        display_table["baseline_accuracy"] = display_table["encoding"].apply(
            lambda enc: f"{baseline_model_metrics[enc]['accuracy']:.4f}"
        )
        display_table["accuracy"] = display_table["accuracy"].apply(
            lambda x: f"{x:.4f}"
        )
        display_table["target_pct_change"] = display_table["target_pct_change"].apply(
            lambda x: f"{x:.1f}%"
        )
        display_table["residual"] = display_table["residual"].apply(
            lambda x: f"{x:.4f}"
        )
        display_table["residual_pct_change"] = display_table[
            "residual_pct_change"
        ].apply(lambda x: f"-{x:.2f}%")

        display_table['Notes'] = display_table['was_clamped'].apply(
            lambda x: '*Target not reached' if x else ''
        )

        column_renames = {
            "encoding": "Encoding",
            "target_pct_change": f'% Change in {attack_config["norm_display"]}',
            "param_value": attack_config["param_display"],
            "baseline_accuracy": "Baseline Accuracy",
            "accuracy": "Accuracy",
            "residual_pct_change": "Decrease in Accuracy (%)",
            "Notes": "Notes"
        }

        final_columns = [
            "Encoding",
            f'% Change in {attack_config["norm_display"]}',
            attack_config["param_display"],
            "Baseline Accuracy",
            "Accuracy",
            "Decrease in Accuracy (%)",
            "Notes"
        ]
        display_table = display_table.rename(columns=column_renames)[final_columns]
        
        pd.set_option("display.max_rows", None)
        pd.set_option("display.max_columns", None)
        pd.set_option("display.width", 1000)
        print(display_table)
        pd.reset_option("display.max_rows")
        pd.reset_option("display.max_columns")
        pd.reset_option("display.width")

    return results_table



def filter_params_for_visibility(results_df, attack_type):
    """Filter parameters for visibility in the plot."""
    if attack_type == "fgsm":
        keep_params = [0.0005, 0.001, 0.01, 0.05, 0.1, 0.5, 1]
    elif attack_type == "cw":
        keep_params = [0.001, 0.01, 0.05, 0.1, 0.5, 1, 10, 100, 1000]
    elif attack_type == "jsma":
        keep_params = [0.0005, 0.001, 0.01, 0.05, 0.1, 0.5, 1]
    results_df = results_df[results_df["param_value"].isin(keep_params)]
    return results_df


def create_accuracy_plot(
    dataset,
    results_df,
    attack_config,
    attack_type,
    training_mode,
    use_all_values=True,
    show_plot=True,
):
    """Create a plot showing accuracy vs attack parameter."""
    plt.figure(figsize=(10, 6))

    if not use_all_values:
        results_df = filter_params_for_visibility(results_df, attack_type)

    param_display = attack_config["param_display"]
    param_format = attack_config["param_format"]

    sns.lineplot(
        data=results_df,
        x="param_value",
        y="accuracy",
        hue="encoding",
        marker="o",
        linewidth=2.5,
        markersize=8,
    )

    plt.xscale("log") 

    param_values = sorted(results_df["param_value"].unique())
    plt.xticks(param_values, [param_format.format(x) for x in param_values])

    plt.xlabel(f"{param_display} (log scale)", fontsize=12)
    plt.ylabel("Accuracy", fontsize=12)
    plt.grid(True, alpha=0.3)
    plt.legend(title="Encoding")

    plt.tight_layout()
    if show_plot:
        plt.show()

    # Save the plot
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    output_path = (
        f"{OUTPUT_DIR}/{dataset}_{attack_type}_baseline_accuracy_comparison.png"
    )
    plt.savefig(output_path)

    if not show_plot:
        plt.close()

    return plt


def create_norm_change_plot(
    dataset,
    results_df,
    attack_config,
    attack_type,
    training_mode,
    use_all_values=True,
    show_plot=True,
):
    """Create a plot showing percent change in norm vs attack parameter."""
    plt.figure(figsize=(10, 6))

    param_display = attack_config["param_display"]
    param_format = attack_config["param_format"]
    norm_type = attack_config["norm_type"]
    norm_display = attack_config["norm_display"]

    if not use_all_values:
        results_df = filter_params_for_visibility(results_df, attack_type)

    sns.lineplot(
        data=results_df,
        x="param_value",
        y=f"pct_change_{norm_type}",
        hue="encoding",
        marker="o",
        linewidth=2.5,
        markersize=8,
    )

    plt.xscale("log") 

    param_values = sorted(results_df["param_value"].unique())
    plt.xticks(param_values, [param_format.format(x) for x in param_values])

    plt.xlabel(f"{param_display} (log scale)", fontsize=12)
    plt.ylabel(f"% Change in {norm_display} Norm", fontsize=12)

    plt.axhline(y=3, color="r", linestyle="--", linewidth=1, label="3% Budget")
    plt.axhline(y=10, color="r", linestyle="--", linewidth=1, label="10% Budget")
    plt.axhline(y=20, color="r", linestyle="--", linewidth=1, label="20% Budget")

    plt.grid(True, alpha=0.3)
    plt.legend(title="Encoding")

    plt.tight_layout()
    if show_plot:
        plt.show()

    os.makedirs(OUTPUT_DIR, exist_ok=True)
    output_path = (
        f"{OUTPUT_DIR}/{dataset}_{attack_type}_baseline_{norm_type}norm_comparison.png"
    )
    plt.savefig(output_path)

    if not show_plot:
        plt.close()

    return plt

def visualize_attack_with_thresholds(
    attack_type="fgsm",
    base_dir="attack_sweep",
    dataset="mirai",
    encodings=["DM", "Stats", "Raw"],
    baseline_model_metrics=None,
    training_mode="baseline",
    interpolation_method="linear",
    thresholds=[3.0, 10.0, 20.0],
    use_all_values=True,
    show_plots=True,
):
    """
    Generate visualizations and analysis for the specified attack type with threshold analysis.
    """
    attack_config = get_attack_config(attack_type)

    file_paths = {}
    for encoding in encodings:
        file_paths[encoding] = (
            f"{base_dir}/{dataset}/{training_mode}/{encoding}_{attack_type}.csv"
        )

    all_data = []
    for encoding, file_path in file_paths.items():
        encoding_data = extract_data(file_path, encoding, attack_config)
        all_data.extend(encoding_data)

    results_df = pd.DataFrame(all_data)

    if results_df.empty:
        print("No data to plot. Exiting.")
        return None, None, None, None

    accuracy_plot = create_accuracy_plot(
        dataset,
        results_df,
        attack_config,
        attack_type,
        training_mode,
        use_all_values,
        show_plots,
    )

    norm_plot = create_norm_change_plot(
        dataset,
        results_df,
        attack_config,
        attack_type,
        training_mode,
        use_all_values,
        show_plots,
    )

    if attack_type == "fgsm":
        pct_change_col = "pct_change_l2"
    elif attack_type == "cw" or attack_type == "deepfool":
        pct_change_col = "pct_change_l2"
    elif attack_type == "jsma":
        pct_change_col = "pct_change_l2"
    
    for encoding in encodings:
        for target_pct_change in [3.0, 10.0, 20.0]:
            suggested_param, _ = estimate_param_for_target_pct_change(
                results_df,
                target_pct_change=target_pct_change,
                param_col="param_value",
                encoding_col="encoding",
                encoding_value=encoding,
                pct_change_col=pct_change_col,
                interpolation_method=interpolation_method,
            )
            print(
                f"Breakpoint {target_pct_change}, Param for {encoding} encoding: {suggested_param:.4f}"
            )

    results_table = analyze_at_threshold(
        attack_type=attack_type,
        results_df=results_df,
        thresholds=thresholds,
        encodings=encodings,
        training_mode=training_mode,
        baseline_model_metrics=baseline_model_metrics,
    )

    return accuracy_plot, norm_plot, results_table, results_df

# %% [markdown]
# ## BASELINE

# %%
TRAINING_MODE = "baseline"

INTERPOLATION_METHOD = "log"

OUTPUT_DIR = "results/attack_sweep/plots"
ENCODINGS = ["DM", "Stats", "Raw"]
BASE_DIR = "results/attack_sweep"

DATASETS = ["mirai", "unsw-nb15"] 
ATTACK_TYPES = ["fgsm", "cw", "jsma"]

for dataset in DATASETS:
    if dataset == "mirai":
        baseline_model_metrics = {
            "DM": {"accuracy": 0.9916},
            "Stats": {"accuracy": 0.9918},
            "Raw": {"accuracy": 0.6817},
            "Flows": {"accuracy": 0.6714}
        }
    elif dataset == "unsw-nb15":
        baseline_model_metrics = {
            "DM": {"accuracy": 0.9682},
            "Stats": {"accuracy": 0.9703},
            "Raw": {"accuracy": 0.8641},  
            "Flows": {"accuracy": 0.8542} 
        }
    else:
        raise ValueError(f"Unsupported dataset: {dataset}")

    for attack_type in ATTACK_TYPES:
        print(f"Running analysis for {dataset} dataset with {attack_type} attack...")
        accuracy_plot, norm_plot, results_table, _ = visualize_attack_with_thresholds(
            attack_type=attack_type,
            base_dir=BASE_DIR,
            dataset=dataset,
            encodings=ENCODINGS,
            training_mode=TRAINING_MODE,
            interpolation_method=INTERPOLATION_METHOD,
            use_all_values=True,
            baseline_model_metrics=baseline_model_metrics,
            show_plots=False,
        )
# Out:
# Running analysis for mirai dataset with fgsm attack...
# Breakpoint 3.0, Param for DM encoding: 0.0024
# Breakpoint 10.0, Param for DM encoding: 0.0095
# Breakpoint 20.0, Param for DM encoding: 0.0196
# Breakpoint 3.0, Param for Stats encoding: 0.0129
# Breakpoint 10.0, Param for Stats encoding: 0.0438
# Breakpoint 20.0, Param for Stats encoding: 0.0882
# Breakpoint 3.0, Param for Raw encoding: 0.0146
# Breakpoint 10.0, Param for Raw encoding: 0.0491
# Breakpoint 20.0, Param for Raw encoding: 0.1002
#
# ================================================================================
# SUMMARY TABLE FOR FGSM ATTACK (baseline)
# ================================================================================
#   Encoding % Change in L2 Epsilon Baseline Accuracy Accuracy Decrease in Accuracy (%) Notes
# 0       DM           3.0%   0.002            0.9916   0.9916                   -0.00%
# 1    Stats           3.0%   0.013            0.9918   0.9916                   -0.02%
# 2      Raw           3.0%   0.015            0.6817   0.4670                  -31.49%
# 3       DM          10.0%   0.009            0.9916   0.9916                   -0.00%
# 4    Stats          10.0%   0.044            0.9918   0.9907                   -0.11%
# 5      Raw          10.0%   0.049            0.6817   0.3905                  -42.71%
# 6       DM          20.0%   0.020            0.9916   0.9364                   -5.57%
# 7    Stats          20.0%   0.088            0.9918   0.7760                  -21.76%
# 8      Raw          20.0%   0.100            0.6817   0.5389                  -20.94%
# Running analysis for mirai dataset with cw attack...
# Breakpoint 3.0, Param for DM encoding: 2.6329
# Breakpoint 10.0, Param for DM encoding: 6.5819
# Breakpoint 20.0, Param for DM encoding: 19.1194
# Breakpoint 3.0, Param for Stats encoding: 5.7543
# Breakpoint 10.0, Param for Stats encoding: 29.4873
# Breakpoint 20.0, Param for Stats encoding: 362.6893
# Breakpoint 3.0, Param for Raw encoding: 5.9096
# Warning: Target 10.0% is above the available range [0.0605%, 3.7269%]. Clamping to max.
# Breakpoint 10.0, Param for Raw encoding: 639.2624
# Warning: Target 20.0% is above the available range [0.0605%, 3.7269%]. Clamping to max.
# Breakpoint 20.0, Param for Raw encoding: 639.2624
# Warning: Target 10.0% is above the available range [0.0605%, 3.7269%]. Clamping to max.
# Warning: Target 20.0% is above the available range [0.0605%, 3.7269%]. Clamping to max.
#
# ================================================================================
# SUMMARY TABLE FOR CW ATTACK (baseline)
# ================================================================================
#   Encoding % Change in L2 C Parameter Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%       2.633            0.9916   0.9087                   -8.36%
# 1    Stats           3.0%       5.754            0.9918   0.8465                  -14.65%
# 2      Raw           3.0%       5.910            0.6817   0.1972                  -71.07%
# 3       DM          10.0%       6.582            0.9916   0.7774                  -21.60%
# 4    Stats          10.0%      29.487            0.9918   0.6170                  -37.79%
# 5      Raw          10.0%     639.262            0.6817   0.2007                  -70.56%  *Target not reached
# 6       DM          20.0%      19.119            0.9916   0.6492                  -34.53%
# 7    Stats          20.0%     362.689            0.9918   0.4288                  -56.76%
# 8      Raw          20.0%     639.262            0.6817   0.2007                  -70.56%  *Target not reached
# Running analysis for mirai dataset with jsma attack...
# Breakpoint 3.0, Param for DM encoding: 0.0054
# Breakpoint 10.0, Param for DM encoding: 0.0236
# Breakpoint 20.0, Param for DM encoding: 0.0506
# Breakpoint 3.0, Param for Stats encoding: 0.0346
# Breakpoint 10.0, Param for Stats encoding: 0.1189
# Breakpoint 20.0, Param for Stats encoding: 0.2702
# Breakpoint 3.0, Param for Raw encoding: 0.0541
# Breakpoint 10.0, Param for Raw encoding: 0.1833
# Breakpoint 20.0, Param for Raw encoding: 0.3686
#
# ================================================================================
# SUMMARY TABLE FOR JSMA ATTACK (baseline)
# ================================================================================
#   Encoding % Change in L2  Theta Baseline Accuracy Accuracy Decrease in Accuracy (%) Notes
# 0       DM           3.0%  0.005            0.9916   0.9916                   -0.00%
# 1    Stats           3.0%  0.035            0.9918   0.9916                   -0.02%
# 2      Raw           3.0%  0.054            0.6817   0.3980                  -41.61%
# 3       DM          10.0%  0.024            0.9916   0.8729                  -11.97%
# 4    Stats          10.0%  0.119            0.9918   0.8882                  -10.45%
# 5      Raw          10.0%  0.183            0.6817   0.3074                  -54.91%
# 6       DM          20.0%  0.051            0.9916   0.7782                  -21.52%
# 7    Stats          20.0%  0.270            0.9918   0.5289                  -46.68%
# 8      Raw          20.0%  0.369            0.6817   0.2884                  -57.69%
# Running analysis for unsw-nb15 dataset with fgsm attack...
# Breakpoint 3.0, Param for DM encoding: 0.0020
# Breakpoint 10.0, Param for DM encoding: 0.0102
# Breakpoint 20.0, Param for DM encoding: 0.0222
# Breakpoint 3.0, Param for Stats encoding: 0.0065
# Breakpoint 10.0, Param for Stats encoding: 0.0232
# Breakpoint 20.0, Param for Stats encoding: 0.0477
# Breakpoint 3.0, Param for Raw encoding: 0.0066
# Breakpoint 10.0, Param for Raw encoding: 0.0224
# Breakpoint 20.0, Param for Raw encoding: 0.0452
#
# ================================================================================
# SUMMARY TABLE FOR FGSM ATTACK (baseline)
# ================================================================================
#   Encoding % Change in L2 Epsilon Baseline Accuracy Accuracy Decrease in Accuracy (%) Notes
# 0       DM           3.0%   0.002            0.9682   0.9429                   -2.62%
# 1    Stats           3.0%   0.007            0.9703   0.9220                   -4.98%
# 2      Raw           3.0%   0.007            0.8641   0.8314                   -3.78%
# 3       DM          10.0%   0.010            0.9682   0.8804                   -9.07%
# 4    Stats          10.0%   0.023            0.9703   0.8329                  -14.16%
# 5      Raw          10.0%   0.022            0.8641   0.7049                  -18.42%
# 6       DM          20.0%   0.022            0.9682   0.8291                  -14.37%
# 7    Stats          20.0%   0.048            0.9703   0.5676                  -41.50%
# 8      Raw          20.0%   0.045            0.8641   0.5674                  -34.33%
# Running analysis for unsw-nb15 dataset with cw attack...
# Breakpoint 3.0, Param for DM encoding: 0.2188
# Breakpoint 10.0, Param for DM encoding: 1.7038
# Breakpoint 20.0, Param for DM encoding: 14.5477
# Breakpoint 3.0, Param for Stats encoding: 0.1014
# Breakpoint 10.0, Param for Stats encoding: 0.3870
# Breakpoint 20.0, Param for Stats encoding: 13.0739
# Breakpoint 3.0, Param for Raw encoding: 0.0263
# Breakpoint 10.0, Param for Raw encoding: 0.1253
# Breakpoint 20.0, Param for Raw encoding: 0.9146
# Warning: Accuracy values contain zeros. Using linear interpolation.
#
# ================================================================================
# SUMMARY TABLE FOR CW ATTACK (baseline)
# ================================================================================
#   Encoding % Change in L2 C Parameter Baseline Accuracy Accuracy Decrease in Accuracy (%) Notes
# 0       DM           3.0%       0.219            0.9682   0.6592                  -31.92%
# 1    Stats           3.0%       0.101            0.9703   0.5876                  -39.44%
# 2      Raw           3.0%       0.026            0.8641   0.4682                  -45.82%
# 3       DM          10.0%       1.704            0.9682   0.2389                  -75.33%
# 4    Stats          10.0%       0.387            0.9703   0.1004                  -89.65%
# 5      Raw          10.0%       0.125            0.8641   0.1814                  -79.01%
# 6       DM          20.0%      14.548            0.9682   0.0167                  -98.28%
# 7    Stats          20.0%      13.074            0.9703   0.0000                 -100.00%
# 8      Raw          20.0%       0.915            0.8641   0.0136                  -98.43%
# Running analysis for unsw-nb15 dataset with jsma attack...
# Breakpoint 3.0, Param for DM encoding: 0.0048
# Breakpoint 10.0, Param for DM encoding: 0.0294
# Breakpoint 20.0, Param for DM encoding: 0.0722
# Breakpoint 3.0, Param for Stats encoding: 0.0178
# Breakpoint 10.0, Param for Stats encoding: 0.0652
# Breakpoint 20.0, Param for Stats encoding: 0.1576
# Breakpoint 3.0, Param for Raw encoding: 0.0161
# Breakpoint 10.0, Param for Raw encoding: 0.0540
# Breakpoint 20.0, Param for Raw encoding: 0.1094
#
# ================================================================================
# SUMMARY TABLE FOR JSMA ATTACK (baseline)
# ================================================================================
#   Encoding % Change in L2  Theta Baseline Accuracy Accuracy Decrease in Accuracy (%) Notes
# 0       DM           3.0%  0.005            0.9682   0.9586                   -0.99%
# 1    Stats           3.0%  0.018            0.9703   0.9277                   -4.39%
# 2      Raw           3.0%  0.016            0.8641   0.8554                   -1.01%
# 3       DM          10.0%  0.029            0.9682   0.8447                  -12.75%
# 4    Stats          10.0%  0.065            0.9703   0.8407                  -13.35%
# 5      Raw          10.0%  0.054            0.8641   0.8237                   -4.68%
# 6       DM          20.0%  0.072            0.9682   0.5028                  -48.07%
# 7    Stats          20.0%  0.158            0.9703   0.1526                  -84.28%
# 8      Raw          20.0%  0.109            0.8641   0.6840                  -20.85%

# %% [markdown]
# ## DEFENSES

# %%
def format_results_for_table(
    results_collection,
    attack_types,
    training_modes,
    eps_values,
    encodings,
    budgets=[3, 10, 20],
):
    """
    Format results into LaTeX tables and CSV files for easy copying.

    Parameters:
    - results_collection: Dictionary where results_collection[budget][encoding][attack][training][eps] = accuracy
    - attack_types: List of attack types (e.g., ['fgsm', 'cw'])
    - training_modes: List of training modes (e.g., ['pgd', 'trades', 'mart'])
    - eps_values: List of epsilon values (e.g., [0.001, 0.01, 0.1])
    - encodings: List of encoding types (e.g., ['DM', 'Stats', 'Raw'])
    - budgets: List of budget percentages (default [3, 10, 20])

    Returns:
    - Dictionary with LaTeX tables and CSV strings for each training mode
    """
    results = {}

    for training_mode in training_modes:
        # Generate LaTeX table
        latex = f"""\\begin{{table*}}[t]
  \\centering
  \\begin{{subtable}}[t]{{0.49\\textwidth}}
    \\caption{{UNSW: Accuracy of defenses}}
    \\label{{tab:unsw_{training_mode}_defense}}
    \\scriptsize
    \\setlength{{\\tabcolsep}}{{2pt}}
      \\begin{{tabular}}{{lc|{('c' * len(eps_values) + '|') * len(attack_types)}}}
    \\toprule
    \\multicolumn{{11}}{{c}}{{\\textbf{{{training_mode.upper()} ($\\epsilon$)}}}} \\\\
    \\cmidrule(lr){{1-{2 + len(attack_types) * len(eps_values)}}}
    \\multirow{{2}}{{*}}{{Budget}} & \\multirow{{2}}{{*}}{{Enc.}} """

        # Add epsilon values headers
        for _ in attack_types:
            for eps in eps_values:
                latex += f"& {eps} "
            latex += "\n       "

        latex += """\\\\
    """

        # Add cmidrules
        start_col = 3
        for _ in range(len(attack_types)):
            end_col = start_col + len(eps_values) - 1
            latex += f"\\cmidrule(lr){{{start_col}-{end_col}}}"
            start_col = end_col + 1

        # Add attack type headers
        latex += "\n      & "
        for attack in attack_types:
            latex += f"& \\multicolumn{{{len(eps_values)}}}{{c|}}{{{attack.upper()}}} "

        latex += """\\\\
    \\midrule\n"""

        # Add data rows
        for budget in budgets:
            latex += f"    \\multirow{{{len(encodings)}}}{{*}}{{{budget}\\%}} \n"

            for encoding in encodings:
                latex += f"     & {encoding}   "

                for attack in attack_types:
                    for eps in eps_values:
                        value = (
                            results_collection.get(budget, {})
                            .get(encoding, {})
                            .get(attack, {})
                            .get(training_mode, {})
                            .get(eps)
                        )
                        latex += f" & {value:.4f}" if value is not None else " & —"

                latex += " \\\\\n"

            if budget != budgets[-1]:
                latex += "    \\midrule\n"

        latex += """    \\bottomrule
  \\end{tabular}
  \\end{subtable}
\\end{table*}"""

        # Generate CSV
        csv = f"Budget,Encoding,"
        for attack in attack_types:
            for eps in eps_values:
                csv += f"{attack.upper()}/{eps},"
        csv = csv[:-1] + "\n"  # Remove trailing comma and add newline

        for budget in budgets:
            for encoding in encodings:
                csv += f"{budget}%,{encoding},"

                for attack in attack_types:
                    for eps in eps_values:
                        value = (
                            results_collection.get(budget, {})
                            .get(encoding, {})
                            .get(attack, {})
                            .get(training_mode, {})
                            .get(eps)
                        )
                        csv += f"{value:.4f}," if value is not None else ","

                csv = csv[:-1] + "\n"  # Remove trailing comma and add newline

        results[training_mode] = {"latex": latex, "csv": csv}

    return results

# %%
DATASET = "mirai" 

ATTACK_TYPES = ["fgsm", 'jsma', "cw"]
TRAINING_MODES = ["pgd", "trades", "mart"]
EPS_VALUES = [0.001, 0.01, 0.1]


INTERPOLATION_METHOD = "log"

OUTPUT_DIR = "results/attack_sweep/plots"
ENCODINGS = ["DM", "Stats", "Raw"]
BASE_DIR = "results/attack_sweep"

if DATASET == "mirai":
    baseline_model_metrics = {
        "DM": {"accuracy": 0.9916},
        "Stats": {"accuracy": 0.9918},
        "Raw": {"accuracy": 0.6817},
    }
elif DATASET == "unsw-nb15":
    baseline_model_metrics = {
        "DM": {"accuracy": 0.9682},
        "Stats": {"accuracy": 0.9703},
        "Raw": {"accuracy": 0.8641},
    }
else:
    raise ValueError(f"Unsupported dataset: {DATASET}")

results_collection = {}


for attack_type in ATTACK_TYPES:
    for training_mode in TRAINING_MODES:
        for eps in EPS_VALUES:
            accuracy_plot, norm_plot, results_table, results_df = (
                visualize_attack_with_thresholds(
                    attack_type=attack_type,
                    base_dir=BASE_DIR,
                    dataset=DATASET,
                    encodings=ENCODINGS,
                    training_mode=f"{training_mode}/eps{eps}",
                    interpolation_method=INTERPOLATION_METHOD,
                    use_all_values=True,
                    baseline_model_metrics=baseline_model_metrics,
                    show_plots=False,
                )
            )
            print(
                f"Results for {attack_type} attack with {training_mode} training and eps={eps}:"
            )

            print(results_df)

            for i, row in results_df.iterrows():
                encoding = row['encoding']
                accuracy = row['accuracy']
                pct_change = row['pct_change_l2']
                
                row_in_encoding_group = i % 3
                
                if row_in_encoding_group == 0:
                    budget = 3
                elif row_in_encoding_group == 1:
                    budget = 10
                else:  
                    budget = 20
                            
                if budget not in results_collection:
                    results_collection[budget] = {}
                if encoding not in results_collection[budget]:
                    results_collection[budget][encoding] = {}
                if attack_type not in results_collection[budget][encoding]:
                    results_collection[budget][encoding][attack_type] = {}
                if training_mode not in results_collection[budget][encoding][attack_type]:
                    results_collection[budget][encoding][attack_type][training_mode] = {}
                
                results_collection[budget][encoding][attack_type][training_mode][eps] = pct_change
# Out:
# Breakpoint 3.0, Param for DM encoding: 0.0024
# Breakpoint 10.0, Param for DM encoding: 0.0094
# Breakpoint 20.0, Param for DM encoding: 0.0194
# Breakpoint 3.0, Param for Stats encoding: 0.0132
# Breakpoint 10.0, Param for Stats encoding: 0.0448
# Warning: Target 20.0% is above the available range [2.9290%, 19.5113%]. Clamping to max.
# Breakpoint 20.0, Param for Stats encoding: 0.0882
# Warning: Target 3.0% is below the available range [3.0290%, 20.2969%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 0.0147
# Breakpoint 10.0, Param for Raw encoding: 0.0492
# Breakpoint 20.0, Param for Raw encoding: 0.1000
# Warning: Target 3.0% is below the available range [3.0290%, 20.2969%]. Clamping to min.
# Warning: Target 20.0% is above the available range [2.9290%, 19.5113%]. Clamping to max.
#
# ================================================================================
# SUMMARY TABLE FOR FGSM ATTACK (pgd/eps0.001)
# ================================================================================
#   Encoding % Change in L2 Epsilon Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%   0.002            0.9916   0.9916                   -0.00%
# 1    Stats           3.0%   0.013            0.9918   0.9914                   -0.04%
# 2      Raw           3.0%   0.015            0.6817   0.5589                  -18.01%  *Target not reached
# 3       DM          10.0%   0.009            0.9916   0.9916                   -0.00%
# 4    Stats          10.0%   0.045            0.9918   0.9811                   -1.08%
# 5      Raw          10.0%   0.049            0.6817   0.4859                  -28.73%
# 6       DM          20.0%   0.019            0.9916   0.8874                  -10.51%
# 7    Stats          20.0%   0.088            0.9918   0.8936                   -9.91%  *Target not reached
# 8      Raw          20.0%   0.100            0.6817   0.4692                  -31.18%
# Results for fgsm attack with pgd training and eps=0.001:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0024  0.991597       2.979524
# 1       DM       0.0095  0.991597      10.124377
# 2       DM       0.0196  0.886088      20.184914
# 3    Stats       0.0129  0.991597       2.929001
# 4    Stats       0.0438  0.984127       9.781199
# 5    Stats       0.0882  0.893557      19.511335
# 6      Raw       0.0147  0.558912       3.029002
# 7      Raw       0.0497  0.485272      10.106395
# 8      Raw       0.1015  0.468824      20.296934
# Warning: Target 3.0% is below the available range [3.0038%, 20.3140%]. Clamping to min.
# Breakpoint 3.0, Param for DM encoding: 0.0024
# Breakpoint 10.0, Param for DM encoding: 0.0093
# Breakpoint 20.0, Param for DM encoding: 0.0193
# Breakpoint 3.0, Param for Stats encoding: 0.0134
# Breakpoint 10.0, Param for Stats encoding: 0.0455
# Warning: Target 20.0% is above the available range [2.8888%, 19.1766%]. Clamping to max.
# Breakpoint 20.0, Param for Stats encoding: 0.0882
# Breakpoint 3.0, Param for Raw encoding: 0.0148
# Breakpoint 10.0, Param for Raw encoding: 0.0500
# Warning: Target 20.0% is above the available range [2.9869%, 19.8826%]. Clamping to max.
# Breakpoint 20.0, Param for Raw encoding: 0.1015
# Warning: Target 3.0% is below the available range [3.0038%, 20.3140%]. Clamping to min.
# Warning: Target 20.0% is above the available range [2.8888%, 19.1766%]. Clamping to max.
# Warning: Target 20.0% is above the available range [2.9869%, 19.8826%]. Clamping to max.
#
# ================================================================================
# SUMMARY TABLE FOR FGSM ATTACK (pgd/eps0.01)
# ================================================================================
#   Encoding % Change in L2 Epsilon Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%   0.002            0.9916   0.9907                   -0.09%  *Target not reached
# 1    Stats           3.0%   0.013            0.9918   0.9916                   -0.02%
# 2      Raw           3.0%   0.015            0.6817   0.6258                   -8.20%
# 3       DM          10.0%   0.009            0.9916   0.9907                   -0.09%
# 4    Stats          10.0%   0.046            0.9918   0.9916                   -0.02%
# 5      Raw          10.0%   0.050            0.6817   0.6258                   -8.20%
# 6       DM          20.0%   0.019            0.9916   0.9907                   -0.09%
# 7    Stats          20.0%   0.088            0.9918   0.9916                   -0.02%  *Target not reached
# 8      Raw          20.0%   0.102            0.6817   0.6258                   -8.20%  *Target not reached
# Results for fgsm attack with pgd training and eps=0.01:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0024  0.990663       3.003814
# 1       DM       0.0095  0.990663      10.190305
# 2       DM       0.0196  0.990663      20.313966
# 3    Stats       0.0129  0.991597       2.888814
# 4    Stats       0.0438  0.991597       9.621659
# 5    Stats       0.0882  0.991597      19.176628
# 6      Raw       0.0147  0.625779       2.986851
# 7      Raw       0.0497  0.625779       9.936194
# 8      Raw       0.1015  0.625779      19.882561
# Breakpoint 3.0, Param for DM encoding: 0.0024
# Breakpoint 10.0, Param for DM encoding: 0.0093
# Breakpoint 20.0, Param for DM encoding: 0.0192
# Breakpoint 3.0, Param for Stats encoding: 0.0135
# Breakpoint 10.0, Param for Stats encoding: 0.0460
# Warning: Target 20.0% is above the available range [2.8730%, 18.9481%]. Clamping to max.
# Breakpoint 20.0, Param for Stats encoding: 0.0882
# Warning: Target 3.0% is below the available range [3.0570%, 20.4088%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 0.0147
# Breakpoint 10.0, Param for Raw encoding: 0.0488
# Breakpoint 20.0, Param for Raw encoding: 0.0994
# Warning: Target 3.0% is below the available range [3.0570%, 20.4088%]. Clamping to min.
# Warning: Target 20.0% is above the available range [2.8730%, 18.9481%]. Clamping to max.
#
# ================================================================================
# SUMMARY TABLE FOR FGSM ATTACK (pgd/eps0.1)
# ================================================================================
#   Encoding % Change in L2 Epsilon Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%   0.002            0.9916   0.9879                   -0.38%
# 1    Stats           3.0%   0.013            0.9918   0.9916                   -0.02%
# 2      Raw           3.0%   0.015            0.6817   0.6258                   -8.20%  *Target not reached
# 3       DM          10.0%   0.009            0.9916   0.9879                   -0.38%
# 4    Stats          10.0%   0.046            0.9918   0.9916                   -0.02%
# 5      Raw          10.0%   0.049            0.6817   0.6258                   -8.20%
# 6       DM          20.0%   0.019            0.9916   0.9879                   -0.38%
# 7    Stats          20.0%   0.088            0.9918   0.9916                   -0.02%  *Target not reached
# 8      Raw          20.0%   0.099            0.6817   0.6258                   -8.20%
# Results for fgsm attack with pgd training and eps=0.1:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0024  0.987862       2.996101
# 1       DM       0.0095  0.987862      10.199291
# 2       DM       0.0196  0.987862      20.384998
# 3    Stats       0.0129  0.991597       2.873018
# 4    Stats       0.0438  0.991597       9.527973
# 5    Stats       0.0882  0.991597      18.948053
# 6      Raw       0.0147  0.625779       3.057019
# 7      Raw       0.0497  0.625779      10.182723
# 8      Raw       0.1015  0.625779      20.408785
# Breakpoint 3.0, Param for DM encoding: 0.0025
# Breakpoint 10.0, Param for DM encoding: 0.0098
# Warning: Target 20.0% is above the available range [2.8820%, 19.3492%]. Clamping to max.
# Breakpoint 20.0, Param for DM encoding: 0.0196
# Breakpoint 3.0, Param for Stats encoding: 0.0132
# Breakpoint 10.0, Param for Stats encoding: 0.0448
# Warning: Target 20.0% is above the available range [2.9247%, 19.5499%]. Clamping to max.
# Breakpoint 20.0, Param for Stats encoding: 0.0882
# Warning: Target 3.0% is below the available range [3.0377%, 20.3268%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 0.0147
# Breakpoint 10.0, Param for Raw encoding: 0.0490
# Breakpoint 20.0, Param for Raw encoding: 0.0998
# Warning: Target 3.0% is below the available range [3.0377%, 20.3268%]. Clamping to min.
# Warning: Target 20.0% is above the available range [2.8820%, 19.3492%]. Clamping to max.
# Warning: Target 20.0% is above the available range [2.9247%, 19.5499%]. Clamping to max.
#
# ================================================================================
# SUMMARY TABLE FOR FGSM ATTACK (trades/eps0.001)
# ================================================================================
#   Encoding % Change in L2 Epsilon Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%   0.003            0.9916   0.9914                   -0.02%
# 1    Stats           3.0%   0.013            0.9918   0.9906                   -0.12%
# 2      Raw           3.0%   0.015            0.6817   0.4707                  -30.96%  *Target not reached
# 3       DM          10.0%   0.010            0.9916   0.9825                   -0.92%
# 4    Stats          10.0%   0.045            0.9918   0.9887                   -0.31%
# 5      Raw          10.0%   0.049            0.6817   0.2233                  -67.25%
# 6       DM          20.0%   0.020            0.9916   0.8796                  -11.30%  *Target not reached
# 7    Stats          20.0%   0.088            0.9918   0.9869                   -0.49%  *Target not reached
# 8      Raw          20.0%   0.100            0.6817   0.2664                  -60.92%
# Results for fgsm attack with trades training and eps=0.001:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0024  0.991597       2.881974
# 1       DM       0.0095  0.986928       9.734396
# 2       DM       0.0196  0.879552      19.349235
# 3    Stats       0.0129  0.990663       2.924660
# 4    Stats       0.0438  0.988796       9.786944
# 5    Stats       0.0882  0.986928      19.549893
# 6      Raw       0.0147  0.470651       3.037739
# 7      Raw       0.0497  0.221350      10.140369
# 8      Raw       0.1015  0.267577      20.326788
# Breakpoint 3.0, Param for DM encoding: 0.0024
# Breakpoint 10.0, Param for DM encoding: 0.0094
# Breakpoint 20.0, Param for DM encoding: 0.0195
# Breakpoint 3.0, Param for Stats encoding: 0.0130
# Breakpoint 10.0, Param for Stats encoding: 0.0437
# Breakpoint 20.0, Param for Stats encoding: 0.0880
# Warning: Target 3.0% is below the available range [3.0449%, 20.3298%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 0.0147
# Breakpoint 10.0, Param for Raw encoding: 0.0489
# Breakpoint 20.0, Param for Raw encoding: 0.0998
# Warning: Target 3.0% is below the available range [3.0449%, 20.3298%]. Clamping to min.
#
# ================================================================================
# SUMMARY TABLE FOR FGSM ATTACK (trades/eps0.01)
# ================================================================================
#   Encoding % Change in L2 Epsilon Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%   0.002            0.9916   0.9907                   -0.09%
# 1    Stats           3.0%   0.013            0.9918   0.9888                   -0.30%
# 2      Raw           3.0%   0.015            0.6817   0.5515                  -19.10%  *Target not reached
# 3       DM          10.0%   0.009            0.9916   0.9907                   -0.09%
# 4    Stats          10.0%   0.044            0.9918   0.9879                   -0.40%
# 5      Raw          10.0%   0.049            0.6817   0.4338                  -36.37%
# 6       DM          20.0%   0.019            0.9916   0.9897                   -0.19%
# 7    Stats          20.0%   0.088            0.9918   0.9860                   -0.58%
# 8      Raw          20.0%   0.100            0.6817   0.2958                  -56.62%
# Results for fgsm attack with trades training and eps=0.01:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0024  0.990663       2.982510
# 1       DM       0.0095  0.990663      10.096929
# 2       DM       0.0196  0.989729      20.120629
# 3    Stats       0.0129  0.988796       2.985924
# 4    Stats       0.0438  0.987862      10.016716
# 5    Stats       0.0882  0.985994      20.038394
# 6      Raw       0.0147  0.551494       3.044871
# 7      Raw       0.0497  0.432380      10.159028
# 8      Raw       0.1015  0.293055      20.329752
# Breakpoint 3.0, Param for DM encoding: 0.0024
# Breakpoint 10.0, Param for DM encoding: 0.0093
# Breakpoint 20.0, Param for DM encoding: 0.0192
# Breakpoint 3.0, Param for Stats encoding: 0.0133
# Breakpoint 10.0, Param for Stats encoding: 0.0448
# Warning: Target 20.0% is above the available range [2.9217%, 19.5460%]. Clamping to max.
# Breakpoint 20.0, Param for Stats encoding: 0.0882
# Warning: Target 3.0% is below the available range [3.0394%, 20.3060%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 0.0147
# Breakpoint 10.0, Param for Raw encoding: 0.0490
# Breakpoint 20.0, Param for Raw encoding: 0.0999
# Warning: Target 3.0% is below the available range [3.0394%, 20.3060%]. Clamping to min.
# Warning: Target 20.0% is above the available range [2.9217%, 19.5460%]. Clamping to max.
#
# ================================================================================
# SUMMARY TABLE FOR FGSM ATTACK (trades/eps0.1)
# ================================================================================
#   Encoding % Change in L2 Epsilon Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%   0.002            0.9916   0.9888                   -0.28%
# 1    Stats           3.0%   0.013            0.9918   0.9888                   -0.30%
# 2      Raw           3.0%   0.015            0.6817   0.6106                  -10.43%  *Target not reached
# 3       DM          10.0%   0.009            0.9916   0.9888                   -0.28%
# 4    Stats          10.0%   0.045            0.9918   0.9879                   -0.40%
# 5      Raw          10.0%   0.049            0.6817   0.5932                  -12.98%
# 6       DM          20.0%   0.019            0.9916   0.9888                   -0.28%
# 7    Stats          20.0%   0.088            0.9918   0.9879                   -0.40%  *Target not reached
# 8      Raw          20.0%   0.100            0.6817   0.5249                  -23.01%
# Results for fgsm attack with trades training and eps=0.1:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0024  0.988796       2.996267
# 1       DM       0.0095  0.988796      10.195626
# 2       DM       0.0196  0.988796      20.380908
# 3    Stats       0.0129  0.988796       2.921669
# 4    Stats       0.0438  0.987862       9.773390
# 5    Stats       0.0882  0.987862      19.546025
# 6      Raw       0.0147  0.610621       3.039425
# 7      Raw       0.0497  0.592991      10.137137
# 8      Raw       0.1015  0.523436      20.306020
# Breakpoint 3.0, Param for DM encoding: 0.0025
# Breakpoint 10.0, Param for DM encoding: 0.0097
# Warning: Target 20.0% is above the available range [2.8977%, 19.5178%]. Clamping to max.
# Breakpoint 20.0, Param for DM encoding: 0.0196
# Breakpoint 3.0, Param for Stats encoding: 0.0131
# Breakpoint 10.0, Param for Stats encoding: 0.0440
# Warning: Target 20.0% is above the available range [2.9656%, 19.9640%]. Clamping to max.
# Breakpoint 20.0, Param for Stats encoding: 0.0882
# Warning: Target 3.0% is below the available range [3.0154%, 20.2023%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 0.0147
# Breakpoint 10.0, Param for Raw encoding: 0.0493
# Breakpoint 20.0, Param for Raw encoding: 0.1005
# Warning: Target 3.0% is below the available range [3.0154%, 20.2023%]. Clamping to min.
# Warning: Target 20.0% is above the available range [2.8977%, 19.5178%]. Clamping to max.
# Warning: Target 20.0% is above the available range [2.9656%, 19.9640%]. Clamping to max.
#
# ================================================================================
# SUMMARY TABLE FOR FGSM ATTACK (mart/eps0.001)
# ================================================================================
#   Encoding % Change in L2 Epsilon Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%   0.002            0.9916   0.9916                   -0.00%
# 1    Stats           3.0%   0.013            0.9918   0.9906                   -0.12%
# 2      Raw           3.0%   0.015            0.6817   0.5524                  -18.97%  *Target not reached
# 3       DM          10.0%   0.010            0.9916   0.9906                   -0.10%
# 4    Stats          10.0%   0.044            0.9918   0.9888                   -0.30%
# 5      Raw          10.0%   0.049            0.6817   0.4529                  -33.56%
# 6       DM          20.0%   0.020            0.9916   0.9897                   -0.19%  *Target not reached
# 7    Stats          20.0%   0.088            0.9918   0.9879                   -0.40%  *Target not reached
# 8      Raw          20.0%   0.100            0.6817   0.3623                  -46.86%
# Results for fgsm attack with mart training and eps=0.001:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0024  0.991597       2.897686
# 1       DM       0.0095  0.990663       9.796550
# 2       DM       0.0196  0.989729      19.517768
# 3    Stats       0.0129  0.990663       2.965566
# 4    Stats       0.0438  0.988796       9.961994
# 5    Stats       0.0882  0.987862      19.963973
# 6      Raw       0.0147  0.552354       3.015367
# 7      Raw       0.0497  0.452376      10.071865
# 8      Raw       0.1015  0.361105      20.202298
# Breakpoint 3.0, Param for DM encoding: 0.0024
# Breakpoint 10.0, Param for DM encoding: 0.0094
# Breakpoint 20.0, Param for DM encoding: 0.0194
# Breakpoint 3.0, Param for Stats encoding: 0.0133
# Breakpoint 10.0, Param for Stats encoding: 0.0451
# Warning: Target 20.0% is above the available range [2.9059%, 19.4457%]. Clamping to max.
# Breakpoint 20.0, Param for Stats encoding: 0.0882
# Warning: Target 3.0% is below the available range [3.0100%, 20.1705%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 0.0147
# Breakpoint 10.0, Param for Raw encoding: 0.0494
# Breakpoint 20.0, Param for Raw encoding: 0.1006
# Warning: Target 3.0% is below the available range [3.0100%, 20.1705%]. Clamping to min.
# Warning: Target 20.0% is above the available range [2.9059%, 19.4457%]. Clamping to max.
#
# ================================================================================
# SUMMARY TABLE FOR FGSM ATTACK (mart/eps0.01)
# ================================================================================
#   Encoding % Change in L2 Epsilon Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%   0.002            0.9916   0.9907                   -0.09%
# 1    Stats           3.0%   0.013            0.9918   0.9915                   -0.03%
# 2      Raw           3.0%   0.015            0.6817   0.6258                   -8.20%  *Target not reached
# 3       DM          10.0%   0.009            0.9916   0.9907                   -0.09%
# 4    Stats          10.0%   0.045            0.9918   0.9897                   -0.21%
# 5      Raw          10.0%   0.049            0.6817   0.6256                   -8.23%
# 6       DM          20.0%   0.019            0.9916   0.9907                   -0.09%
# 7    Stats          20.0%   0.088            0.9918   0.9888                   -0.30%  *Target not reached
# 8      Raw          20.0%   0.101            0.6817   0.6472                   -5.06%
# Results for fgsm attack with mart training and eps=0.01:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0024  0.990663       2.967385
# 1       DM       0.0095  0.990663      10.109068
# 2       DM       0.0196  0.990663      20.227504
# 3    Stats       0.0129  0.991597       2.905890
# 4    Stats       0.0438  0.989729       9.720826
# 5    Stats       0.0882  0.988796      19.445725
# 6      Raw       0.0147  0.625779       3.009986
# 7      Raw       0.0497  0.625564      10.051513
# 8      Raw       0.1015  0.647495      20.170548
# Breakpoint 3.0, Param for DM encoding: 0.0025
# Breakpoint 10.0, Param for DM encoding: 0.0096
# Warning: Target 20.0% is above the available range [2.9290%, 19.8229%]. Clamping to max.
# Breakpoint 20.0, Param for DM encoding: 0.0196
# Breakpoint 3.0, Param for Stats encoding: 0.0130
# Breakpoint 10.0, Param for Stats encoding: 0.0437
# Breakpoint 20.0, Param for Stats encoding: 0.0878
# Breakpoint 3.0, Param for Raw encoding: 0.0148
# Breakpoint 10.0, Param for Raw encoding: 0.0499
# Warning: Target 20.0% is above the available range [2.9887%, 19.9889%]. Clamping to max.
# Breakpoint 20.0, Param for Raw encoding: 0.1015
# Warning: Target 20.0% is above the available range [2.9290%, 19.8229%]. Clamping to max.
# Warning: Target 20.0% is above the available range [2.9887%, 19.9889%]. Clamping to max.
#
# ================================================================================
# SUMMARY TABLE FOR FGSM ATTACK (mart/eps0.1)
# ================================================================================
#   Encoding % Change in L2 Epsilon Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%   0.002            0.9916   0.9906                   -0.10%
# 1    Stats           3.0%   0.013            0.9918   0.9888                   -0.30%
# 2      Raw           3.0%   0.015            0.6817   0.6258                   -8.20%
# 3       DM          10.0%   0.010            0.9916   0.9897                   -0.19%
# 4    Stats          10.0%   0.044            0.9918   0.9888                   -0.30%
# 5      Raw          10.0%   0.050            0.6817   0.6258                   -8.20%
# 6       DM          20.0%   0.020            0.9916   0.9888                   -0.28%  *Target not reached
# 7    Stats          20.0%   0.088            0.9918   0.9879                   -0.40%
# 8      Raw          20.0%   0.102            0.6817   0.6257                   -8.22%  *Target not reached
# Results for fgsm attack with mart training and eps=0.1:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0024  0.990663       2.928954
# 1       DM       0.0095  0.989729       9.937487
# 2       DM       0.0196  0.988796      19.822944
# 3    Stats       0.0129  0.988796       2.980340
# 4    Stats       0.0438  0.988796      10.025328
# 5    Stats       0.0882  0.987862      20.084427
# 6      Raw       0.0147  0.625779       2.988735
# 7      Raw       0.0497  0.625779       9.969120
# 8      Raw       0.1015  0.625672      19.988867
# Breakpoint 3.0, Param for DM encoding: 0.0060
# Breakpoint 10.0, Param for DM encoding: 0.0235
# Warning: Target 20.0% is above the available range [2.7246%, 17.1606%]. Clamping to max.
# Breakpoint 20.0, Param for DM encoding: 0.0506
# Breakpoint 3.0, Param for Stats encoding: 0.0347
# Breakpoint 10.0, Param for Stats encoding: 0.1159
# Breakpoint 20.0, Param for Stats encoding: 0.2579
# Warning: Target 3.0% is below the available range [3.1712%, 21.8446%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 0.0560
# Breakpoint 10.0, Param for Raw encoding: 0.1853
# Breakpoint 20.0, Param for Raw encoding: 0.4066
# Warning: Target 3.0% is below the available range [3.1712%, 21.8446%]. Clamping to min.
# Warning: Target 20.0% is above the available range [2.7246%, 17.1606%]. Clamping to max.
#
# ================================================================================
# SUMMARY TABLE FOR JSMA ATTACK (pgd/eps0.001)
# ================================================================================
#   Encoding % Change in L2  Theta Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%  0.006            0.9916   0.9897                   -0.19%
# 1    Stats           3.0%  0.035            0.9918   0.9916                   -0.02%
# 2      Raw           3.0%  0.056            0.6817   0.5405                  -20.71%  *Target not reached
# 3       DM          10.0%  0.023            0.9916   0.9665                   -2.53%
# 4    Stats          10.0%  0.116            0.9918   0.9815                   -1.03%
# 5      Raw          10.0%  0.185            0.6817   0.3598                  -47.22%
# 6       DM          20.0%  0.051            0.9916   0.4949                  -50.09%  *Target not reached
# 7    Stats          20.0%  0.258            0.9918   0.3704                  -62.66%
# 8      Raw          20.0%  0.407            0.6817   0.0864                  -87.32%
# Results for jsma attack with pgd training and eps=0.001:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0054  0.991597       2.724550
# 1       DM       0.0236  0.966387      10.052486
# 2       DM       0.0506  0.494865      17.160624
# 3    Stats       0.0346  0.991597       2.994404
# 4    Stats       0.1189  0.981326      10.257036
# 5    Stats       0.2702  0.349206      20.823131
# 6      Raw       0.0560  0.540529       3.171215
# 7      Raw       0.2099  0.344872      11.270178
# 8      Raw       0.4501  0.069877      21.844570
# Breakpoint 3.0, Param for DM encoding: 0.0060
# Breakpoint 10.0, Param for DM encoding: 0.0233
# Breakpoint 20.0, Param for DM encoding: 0.0480
# Breakpoint 3.0, Param for Stats encoding: 0.0347
# Breakpoint 10.0, Param for Stats encoding: 0.1160
# Breakpoint 20.0, Param for Stats encoding: 0.2347
# Warning: Target 3.0% is below the available range [4.1982%, 26.9589%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 0.0560
# Breakpoint 10.0, Param for Raw encoding: 0.1335
# Breakpoint 20.0, Param for Raw encoding: 0.2950
# Warning: Target 3.0% is below the available range [4.1982%, 26.9589%]. Clamping to min.
#
# ================================================================================
# SUMMARY TABLE FOR JSMA ATTACK (pgd/eps0.01)
# ================================================================================
#   Encoding % Change in L2  Theta Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%  0.006            0.9916   0.9915                   -0.01%
# 1    Stats           3.0%  0.035            0.9918   0.9916                   -0.02%
# 2      Raw           3.0%  0.056            0.6817   0.6258                   -8.20%  *Target not reached
# 3       DM          10.0%  0.023            0.9916   0.9907                   -0.09%
# 4    Stats          10.0%  0.116            0.9918   0.9916                   -0.02%
# 5      Raw          10.0%  0.133            0.6817   0.6256                   -8.23%
# 6       DM          20.0%  0.048            0.9916   0.9907                   -0.09%
# 7    Stats          20.0%  0.235            0.9918   0.8438                  -14.92%
# 8      Raw          20.0%  0.295            0.6817   0.5608                  -17.74%
# Results for jsma attack with pgd training and eps=0.01:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0054  0.991597       2.724550
# 1       DM       0.0236  0.990663      10.098352
# 2       DM       0.0506  0.990663      21.055291
# 3    Stats       0.0346  0.991597       2.993499
# 4    Stats       0.1189  0.991597      10.251901
# 5    Stats       0.2702  0.816060      22.967300
# 6      Raw       0.0560  0.625779       4.198159
# 7      Raw       0.2099  0.625457      15.722000
# 8      Raw       0.4501  0.489787      26.958946
# Breakpoint 3.0, Param for DM encoding: 0.0060
# Breakpoint 10.0, Param for DM encoding: 0.0234
# Breakpoint 20.0, Param for DM encoding: 0.0481
# Breakpoint 3.0, Param for Stats encoding: 0.0347
# Breakpoint 10.0, Param for Stats encoding: 0.1162
# Breakpoint 20.0, Param for Stats encoding: 0.2341
# Warning: Target 3.0% is below the available range [3.8770%, 26.8903%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 0.0560
# Breakpoint 10.0, Param for Raw encoding: 0.1450
# Breakpoint 20.0, Param for Raw encoding: 0.3128
# Warning: Target 3.0% is below the available range [3.8770%, 26.8903%]. Clamping to min.
#
# ================================================================================
# SUMMARY TABLE FOR JSMA ATTACK (pgd/eps0.1)
# ================================================================================
#   Encoding % Change in L2  Theta Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%  0.006            0.9916   0.9879                   -0.38%
# 1    Stats           3.0%  0.035            0.9918   0.9916                   -0.02%
# 2      Raw           3.0%  0.056            0.6817   0.6258                   -8.20%  *Target not reached
# 3       DM          10.0%  0.023            0.9916   0.9879                   -0.38%
# 4    Stats          10.0%  0.116            0.9918   0.9916                   -0.02%
# 5      Raw          10.0%  0.145            0.6817   0.6258                   -8.20%
# 6       DM          20.0%  0.048            0.9916   0.9879                   -0.38%
# 7    Stats          20.0%  0.234            0.9918   0.9901                   -0.18%
# 8      Raw          20.0%  0.313            0.6817   0.6257                   -8.22%
# Results for jsma attack with pgd training and eps=0.1:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0054  0.987862       2.718311
# 1       DM       0.0236  0.987862      10.072146
# 2       DM       0.0506  0.987862      21.004626
# 3    Stats       0.0346  0.991597       2.993898
# 4    Stats       0.1189  0.991597      10.227771
# 5    Stats       0.2702  0.989729      23.049353
# 6      Raw       0.0560  0.625779       3.876974
# 7      Raw       0.2099  0.625779      14.458484
# 8      Raw       0.4501  0.625564      26.890303
# Breakpoint 3.0, Param for DM encoding: 0.0060
# Breakpoint 10.0, Param for DM encoding: 0.0234
# Warning: Target 20.0% is above the available range [2.7246%, 19.8798%]. Clamping to max.
# Breakpoint 20.0, Param for DM encoding: 0.0506
# Breakpoint 3.0, Param for Stats encoding: 0.0347
# Breakpoint 10.0, Param for Stats encoding: 0.1159
# Breakpoint 20.0, Param for Stats encoding: 0.2322
# Warning: Target 3.0% is below the available range [3.1380%, 22.7874%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 0.0560
# Breakpoint 10.0, Param for Raw encoding: 0.1908
# Breakpoint 20.0, Param for Raw encoding: 0.3930
# Warning: Target 3.0% is below the available range [3.1380%, 22.7874%]. Clamping to min.
# Warning: Target 20.0% is above the available range [2.7246%, 19.8798%]. Clamping to max.
#
# ================================================================================
# SUMMARY TABLE FOR JSMA ATTACK (trades/eps0.001)
# ================================================================================
#   Encoding % Change in L2  Theta Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%  0.006            0.9916   0.9913                   -0.03%
# 1    Stats           3.0%  0.035            0.9918   0.9916                   -0.02%
# 2      Raw           3.0%  0.056            0.6817   0.4539                  -33.42%  *Target not reached
# 3       DM          10.0%  0.023            0.9916   0.9879                   -0.37%
# 4    Stats          10.0%  0.116            0.9918   0.9889                   -0.30%
# 5      Raw          10.0%  0.191            0.6817   0.1956                  -71.31%
# 6       DM          20.0%  0.051            0.9916   0.6200                  -37.48%  *Target not reached
# 7    Stats          20.0%  0.232            0.9918   0.9865                   -0.53%
# 8      Raw          20.0%  0.393            0.6817   0.1705                  -74.98%
# Results for jsma attack with trades training and eps=0.001:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0054  0.991597       2.724550
# 1       DM       0.0236  0.987862      10.094418
# 2       DM       0.0506  0.619981      19.879800
# 3    Stats       0.0346  0.991597       2.994554
# 4    Stats       0.1189  0.988796      10.256264
# 5    Stats       0.2702  0.985994      23.259419
# 6      Raw       0.0560  0.453881       3.138038
# 7      Raw       0.2099  0.183186      10.941780
# 8      Raw       0.4501  0.167921      22.787367
# Breakpoint 3.0, Param for DM encoding: 0.0060
# Breakpoint 10.0, Param for DM encoding: 0.0234
# Breakpoint 20.0, Param for DM encoding: 0.0480
# Breakpoint 3.0, Param for Stats encoding: 0.0348
# Breakpoint 10.0, Param for Stats encoding: 0.1161
# Breakpoint 20.0, Param for Stats encoding: 0.2326
# Warning: Target 3.0% is below the available range [3.2034%, 22.6362%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 0.0560
# Breakpoint 10.0, Param for Raw encoding: 0.1874
# Breakpoint 20.0, Param for Raw encoding: 0.3941
# Warning: Target 3.0% is below the available range [3.2034%, 22.6362%]. Clamping to min.
#
# ================================================================================
# SUMMARY TABLE FOR JSMA ATTACK (trades/eps0.01)
# ================================================================================
#   Encoding % Change in L2  Theta Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%  0.006            0.9916   0.9907                   -0.09%
# 1    Stats           3.0%  0.035            0.9918   0.9888                   -0.30%
# 2      Raw           3.0%  0.056            0.6817   0.5396                  -20.85%  *Target not reached
# 3       DM          10.0%  0.023            0.9916   0.9907                   -0.09%
# 4    Stats          10.0%  0.116            0.9918   0.9879                   -0.40%
# 5      Raw          10.0%  0.187            0.6817   0.2872                  -57.87%
# 6       DM          20.0%  0.048            0.9916   0.9907                   -0.09%
# 7    Stats          20.0%  0.233            0.9918   0.9856                   -0.63%
# 8      Raw          20.0%  0.394            0.6817   0.1412                  -79.28%
# Results for jsma attack with trades training and eps=0.01:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0054  0.990663       2.722477
# 1       DM       0.0236  0.990663      10.090696
# 2       DM       0.0506  0.990663      21.045869
# 3    Stats       0.0346  0.988796       2.986587
# 4    Stats       0.1189  0.987862      10.242603
# 5    Stats       0.2702  0.985061      23.227015
# 6      Raw       0.0560  0.539561       3.203368
# 7      Raw       0.2099  0.270694      11.126253
# 8      Raw       0.4501  0.123092      22.636209
# Breakpoint 3.0, Param for DM encoding: 0.0060
# Breakpoint 10.0, Param for DM encoding: 0.0234
# Breakpoint 20.0, Param for DM encoding: 0.0481
# Breakpoint 3.0, Param for Stats encoding: 0.0348
# Breakpoint 10.0, Param for Stats encoding: 0.1161
# Breakpoint 20.0, Param for Stats encoding: 0.2323
# Warning: Target 3.0% is below the available range [3.2719%, 22.6698%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 0.0560
# Breakpoint 10.0, Param for Raw encoding: 0.1819
# Breakpoint 20.0, Param for Raw encoding: 0.3913
# Warning: Target 3.0% is below the available range [3.2719%, 22.6698%]. Clamping to min.
#
# ================================================================================
# SUMMARY TABLE FOR JSMA ATTACK (trades/eps0.1)
# ================================================================================
#   Encoding % Change in L2  Theta Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%  0.006            0.9916   0.9888                   -0.28%
# 1    Stats           3.0%  0.035            0.9918   0.9888                   -0.30%
# 2      Raw           3.0%  0.056            0.6817   0.6029                  -11.56%  *Target not reached
# 3       DM          10.0%  0.023            0.9916   0.9888                   -0.28%
# 4    Stats          10.0%  0.116            0.9918   0.9888                   -0.30%
# 5      Raw          10.0%  0.182            0.6817   0.2687                  -60.59%
# 6       DM          20.0%  0.048            0.9916   0.9888                   -0.28%
# 7    Stats          20.0%  0.232            0.9918   0.9880                   -0.38%
# 8      Raw          20.0%  0.391            0.6817   0.1450                  -78.74%
# Results for jsma attack with trades training and eps=0.1:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0054  0.988796       2.718333
# 1       DM       0.0236  0.988796      10.072582
# 2       DM       0.0506  0.988796      21.006682
# 3    Stats       0.0346  0.988796       2.987012
# 4    Stats       0.1189  0.988796      10.240831
# 5    Stats       0.2702  0.987862      23.264578
# 6      Raw       0.0560  0.602881       3.271910
# 7      Raw       0.2099  0.243604      11.451180
# 8      Raw       0.4501  0.129005      22.669806
# Breakpoint 3.0, Param for DM encoding: 0.0060
# Breakpoint 10.0, Param for DM encoding: 0.0233
# Breakpoint 20.0, Param for DM encoding: 0.0502
# Breakpoint 3.0, Param for Stats encoding: 0.0347
# Breakpoint 10.0, Param for Stats encoding: 0.1159
# Breakpoint 20.0, Param for Stats encoding: 0.2321
# Warning: Target 3.0% is below the available range [3.2124%, 22.8517%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 0.0560
# Breakpoint 10.0, Param for Raw encoding: 0.1862
# Breakpoint 20.0, Param for Raw encoding: 0.3903
# Warning: Target 3.0% is below the available range [3.2124%, 22.8517%]. Clamping to min.
#
# ================================================================================
# SUMMARY TABLE FOR JSMA ATTACK (mart/eps0.001)
# ================================================================================
#   Encoding % Change in L2  Theta Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%  0.006            0.9916   0.9915                   -0.01%
# 1    Stats           3.0%  0.035            0.9918   0.9907                   -0.12%
# 2      Raw           3.0%  0.056            0.6817   0.5565                  -18.36%  *Target not reached
# 3       DM          10.0%  0.023            0.9916   0.9907                   -0.09%
# 4    Stats          10.0%  0.116            0.9918   0.9888                   -0.30%
# 5      Raw          10.0%  0.186            0.6817   0.3397                  -50.17%
# 6       DM          20.0%  0.050            0.9916   0.7352                  -25.86%
# 7    Stats          20.0%  0.232            0.9918   0.9865                   -0.53%
# 8      Raw          20.0%  0.390            0.6817   0.1996                  -70.72%
# Results for jsma attack with mart training and eps=0.001:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0054  0.991597       2.724550
# 1       DM       0.0236  0.990663      10.098881
# 2       DM       0.0506  0.732960      20.138190
# 3    Stats       0.0346  0.990663       2.992154
# 4    Stats       0.1189  0.988796      10.258682
# 5    Stats       0.2702  0.985994      23.282292
# 6      Raw       0.0560  0.556547       3.212354
# 7      Raw       0.2099  0.323371      11.198935
# 8      Raw       0.4501  0.178671      22.851733
# Breakpoint 3.0, Param for DM encoding: 0.0060
# Breakpoint 10.0, Param for DM encoding: 0.0233
# Breakpoint 20.0, Param for DM encoding: 0.0491
# Breakpoint 3.0, Param for Stats encoding: 0.0347
# Breakpoint 10.0, Param for Stats encoding: 0.1158
# Breakpoint 20.0, Param for Stats encoding: 0.2318
# Warning: Target 3.0% is below the available range [3.7895%, 26.6556%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 0.0560
# Breakpoint 10.0, Param for Raw encoding: 0.1573
# Breakpoint 20.0, Param for Raw encoding: 0.3305
# Warning: Target 3.0% is below the available range [3.7895%, 26.6556%]. Clamping to min.
#
# ================================================================================
# SUMMARY TABLE FOR JSMA ATTACK (mart/eps0.01)
# ================================================================================
#   Encoding % Change in L2  Theta Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%  0.006            0.9916   0.9915                   -0.01%
# 1    Stats           3.0%  0.035            0.9918   0.9916                   -0.02%
# 2      Raw           3.0%  0.056            0.6817   0.6256                   -8.23%  *Target not reached
# 3       DM          10.0%  0.023            0.9916   0.9907                   -0.09%
# 4    Stats          10.0%  0.116            0.9918   0.9907                   -0.11%
# 5      Raw          10.0%  0.157            0.6817   0.6237                   -8.51%
# 6       DM          20.0%  0.049            0.9916   0.8631                  -12.96%
# 7    Stats          20.0%  0.232            0.9918   0.9701                   -2.19%
# 8      Raw          20.0%  0.331            0.6817   0.5710                  -16.24%
# Results for jsma attack with mart training and eps=0.01:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0054  0.991597       2.724552
# 1       DM       0.0236  0.990663      10.095368
# 2       DM       0.0506  0.858077      20.584171
# 3    Stats       0.0346  0.991597       2.995171
# 4    Stats       0.1189  0.990663      10.269844
# 5    Stats       0.2702  0.965453      23.301868
# 6      Raw       0.0560  0.625564       3.789486
# 7      Raw       0.2099  0.623199      13.108343
# 8      Raw       0.4501  0.538056      26.655585
# Breakpoint 3.0, Param for DM encoding: 0.0060
# Breakpoint 10.0, Param for DM encoding: 0.0234
# Breakpoint 20.0, Param for DM encoding: 0.0480
# Breakpoint 3.0, Param for Stats encoding: 0.0348
# Breakpoint 10.0, Param for Stats encoding: 0.1161
# Breakpoint 20.0, Param for Stats encoding: 0.2323
# Warning: Target 3.0% is below the available range [3.9760%, 27.3205%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 0.0560
# Breakpoint 10.0, Param for Raw encoding: 0.1522
# Breakpoint 20.0, Param for Raw encoding: 0.3217
# Warning: Target 3.0% is below the available range [3.9760%, 27.3205%]. Clamping to min.
#
# ================================================================================
# SUMMARY TABLE FOR JSMA ATTACK (mart/eps0.1)
# ================================================================================
#   Encoding % Change in L2  Theta Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%  0.006            0.9916   0.9907                   -0.09%
# 1    Stats           3.0%  0.035            0.9918   0.9888                   -0.30%
# 2      Raw           3.0%  0.056            0.6817   0.6258                   -8.20%  *Target not reached
# 3       DM          10.0%  0.023            0.9916   0.9907                   -0.09%
# 4    Stats          10.0%  0.116            0.9918   0.9888                   -0.30%
# 5      Raw          10.0%  0.152            0.6817   0.6255                   -8.25%
# 6       DM          20.0%  0.048            0.9916   0.9898                   -0.18%
# 7    Stats          20.0%  0.232            0.9918   0.9873                   -0.46%
# 8      Raw          20.0%  0.322            0.6817   0.5865                  -13.97%
# Results for jsma attack with mart training and eps=0.1:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       0.0054  0.990663       2.722488
# 1       DM       0.0236  0.990663      10.091822
# 2       DM       0.0506  0.989729      21.055655
# 3    Stats       0.0346  0.988796       2.986694
# 4    Stats       0.1189  0.988796      10.244116
# 5    Stats       0.2702  0.986928      23.261231
# 6      Raw       0.0560  0.625779       3.975987
# 7      Raw       0.2099  0.625349      13.456756
# 8      Raw       0.4501  0.557622      27.320541
# Warning: Target 3.0% is below the available range [16.2992%, 51.2876%]. Clamping to min.
# Breakpoint 3.0, Param for DM encoding: 2.6329
# Warning: Target 10.0% is below the available range [16.2992%, 51.2876%]. Clamping to min.
# Breakpoint 10.0, Param for DM encoding: 2.6329
# Breakpoint 20.0, Param for DM encoding: 3.4031
# Warning: Target 3.0% is below the available range [17.0974%, 32.3759%]. Clamping to min.
# Breakpoint 3.0, Param for Stats encoding: 5.7543
# Warning: Target 10.0% is below the available range [17.0974%, 32.3759%]. Clamping to min.
# Breakpoint 10.0, Param for Stats encoding: 5.7543
# Breakpoint 20.0, Param for Stats encoding: 10.9792
# Warning: Target 3.0% is below the available range [3.8933%, 6.4202%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 4.4241
# Warning: Target 10.0% is above the available range [3.8933%, 6.4202%]. Clamping to max.
# Breakpoint 10.0, Param for Raw encoding: 1000.0000
# Warning: Target 20.0% is above the available range [3.8933%, 6.4202%]. Clamping to max.
# Breakpoint 20.0, Param for Raw encoding: 1000.0000
# Warning: Target 3.0% is below the available range [16.2992%, 51.2876%]. Clamping to min.
# Warning: Target 3.0% is below the available range [17.0974%, 32.3759%]. Clamping to min.
# Warning: Target 3.0% is below the available range [3.8933%, 6.4202%]. Clamping to min.
# Warning: Target 10.0% is below the available range [16.2992%, 51.2876%]. Clamping to min.
# Warning: Target 10.0% is below the available range [17.0974%, 32.3759%]. Clamping to min.
# Warning: Target 10.0% is above the available range [3.8933%, 6.4202%]. Clamping to max.
# Warning: Target 20.0% is above the available range [3.8933%, 6.4202%]. Clamping to max.
#
# ================================================================================
# SUMMARY TABLE FOR CW ATTACK (pgd/eps0.001)
# ================================================================================
# ...
# Warning: Target 20.0% is above the available range [2.2372%, 4.7083%]. Clamping to max.
#
# ================================================================================
# SUMMARY TABLE FOR CW ATTACK (trades/eps0.01)
# ================================================================================
#   Encoding % Change in L2 C Parameter Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%       2.633            0.9916   0.6639                  -33.05%  *Target not reached
# 1    Stats           3.0%       8.566            0.9918   0.8330                  -16.02%
# 2      Raw           3.0%      37.504            0.6817   0.3078                  -54.85%
# 3       DM          10.0%       2.633            0.9916   0.6639                  -33.05%  *Target not reached
# 4    Stats          10.0%      18.997            0.9918   0.6561                  -33.84%
# 5      Raw          10.0%    1000.000            0.6817   0.2780                  -59.22%  *Target not reached
# 6       DM          20.0%      16.858            0.9916   0.5693                  -42.59%
# 7    Stats          20.0%      33.996            0.9918   0.5648                  -43.05%
# 8      Raw          20.0%    1000.000            0.6817   0.2780                  -59.22%  *Target not reached
# Results for cw attack with trades training and eps=0.01:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       2.6329  0.663866      11.812209
# 1       DM       6.5819  0.618114      14.783672
# 2       DM      19.1194  0.563025      20.825511
# 3    Stats       5.7543  0.938375       1.644265
# 4    Stats      29.4873  0.575163      19.436275
# 5    Stats     362.6893  0.417367      32.184037
# 6      Raw       4.4241  0.328854       2.237166
# 7      Raw    1000.0000  0.278005       4.708263
# 8      Raw    1000.0000  0.278005       4.708263
# Warning: Target 3.0% is below the available range [4.4783%, 48.7944%]. Clamping to min.
# Breakpoint 3.0, Param for DM encoding: 2.6329
# Breakpoint 10.0, Param for DM encoding: 3.7972
# Breakpoint 20.0, Param for DM encoding: 5.2080
# Warning: Target 3.0% is below the available range [3.6330%, 40.5076%]. Clamping to min.
# Breakpoint 3.0, Param for Stats encoding: 5.7543
# Breakpoint 10.0, Param for Stats encoding: 13.0105
# Breakpoint 20.0, Param for Stats encoding: 22.7425
# Warning: Target 3.0% is above the available range [0.4709%, 0.9812%]. Clamping to max.
# Breakpoint 3.0, Param for Raw encoding: 1000.0000
# Warning: Target 10.0% is above the available range [0.4709%, 0.9812%]. Clamping to max.
# Breakpoint 10.0, Param for Raw encoding: 1000.0000
# Warning: Target 20.0% is above the available range [0.4709%, 0.9812%]. Clamping to max.
# Breakpoint 20.0, Param for Raw encoding: 1000.0000
# Warning: Target 3.0% is below the available range [4.4783%, 48.7944%]. Clamping to min.
# Warning: Target 3.0% is below the available range [3.6330%, 40.5076%]. Clamping to min.
# Warning: Target 3.0% is above the available range [0.4709%, 0.9812%]. Clamping to max.
# Warning: Target 10.0% is above the available range [0.4709%, 0.9812%]. Clamping to max.
# Warning: Target 20.0% is above the available range [0.4709%, 0.9812%]. Clamping to max.
#
# ================================================================================
# SUMMARY TABLE FOR CW ATTACK (trades/eps0.1)
# ================================================================================
#   Encoding % Change in L2 C Parameter Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%       2.633            0.9916   0.9122                   -8.00%  *Target not reached
# 1    Stats           3.0%       5.754            0.9918   0.8889                  -10.38%  *Target not reached
# 2      Raw           3.0%    1000.000            0.6817   0.5667                  -16.88%  *Target not reached
# 3       DM          10.0%       3.797            0.9916   0.7013                  -29.27%
# 4    Stats          10.0%      13.010            0.9918   0.5758                  -41.94%
# 5      Raw          10.0%    1000.000            0.6817   0.5667                  -16.88%  *Target not reached
# 6       DM          20.0%       5.208            0.9916   0.5590                  -43.63%
# 7    Stats          20.0%      22.743            0.9918   0.4278                  -56.87%
# 8      Raw          20.0%    1000.000            0.6817   0.5667                  -16.88%  *Target not reached
# Results for cw attack with trades training and eps=0.1:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       2.6329  0.912232       4.478336
# 1       DM       6.5819  0.472456      33.427770
# 2       DM      19.1194  0.267974      48.794358
# 3    Stats       5.7543  0.888889       3.633019
# 4    Stats      29.4873  0.372549      27.607300
# 5    Stats     362.6893  0.236228      40.507586
# 6      Raw       4.4241  0.582240       0.470945
# 7      Raw    1000.0000  0.566652       0.981153
# 8      Raw    1000.0000  0.566652       0.981153
# Warning: Target 3.0% is below the available range [21.7576%, 47.0836%]. Clamping to min.
# Breakpoint 3.0, Param for DM encoding: 2.6329
# Warning: Target 10.0% is below the available range [21.7576%, 47.0836%]. Clamping to min.
# Breakpoint 10.0, Param for DM encoding: 2.6329
# Warning: Target 20.0% is below the available range [21.7576%, 47.0836%]. Clamping to min.
# Breakpoint 20.0, Param for DM encoding: 2.6329
# Warning: Target 3.0% is below the available range [22.3896%, 45.7400%]. Clamping to min.
# Breakpoint 3.0, Param for Stats encoding: 5.7543
# Warning: Target 10.0% is below the available range [22.3896%, 45.7400%]. Clamping to min.
# Breakpoint 10.0, Param for Stats encoding: 5.7543
# Warning: Target 20.0% is below the available range [22.3896%, 45.7400%]. Clamping to min.
# Breakpoint 20.0, Param for Stats encoding: 5.7543
# Warning: Target 3.0% is below the available range [5.4335%, 11.0694%]. Clamping to min.
# Breakpoint 3.0, Param for Raw encoding: 4.4241
# Breakpoint 10.0, Param for Raw encoding: 461.1768
# Warning: Target 20.0% is above the available range [5.4335%, 11.0694%]. Clamping to max.
# Breakpoint 20.0, Param for Raw encoding: 1000.0000
# Warning: Target 3.0% is below the available range [21.7576%, 47.0836%]. Clamping to min.
# Warning: Target 3.0% is below the available range [22.3896%, 45.7400%]. Clamping to min.
# Warning: Target 3.0% is below the available range [5.4335%, 11.0694%]. Clamping to min.
# Warning: Target 10.0% is below the available range [21.7576%, 47.0836%]. Clamping to min.
# Warning: Target 10.0% is below the available range [22.3896%, 45.7400%]. Clamping to min.
# Warning: Target 20.0% is below the available range [21.7576%, 47.0836%]. Clamping to min.
# Warning: Target 20.0% is below the available range [22.3896%, 45.7400%]. Clamping to min.
# Warning: Target 20.0% is above the available range [5.4335%, 11.0694%]. Clamping to max.
#
# ================================================================================
# SUMMARY TABLE FOR CW ATTACK (mart/eps0.001)
# ================================================================================
#   Encoding % Change in L2 C Parameter Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%       2.633            0.9916   0.4650                  -53.11%  *Target not reached
# 1    Stats           3.0%       5.754            0.9918   0.3445                  -65.26%  *Target not reached
# 2      Raw           3.0%       4.424            0.6817   0.2294                  -66.35%  *Target not reached
# 3       DM          10.0%       2.633            0.9916   0.4650                  -53.11%  *Target not reached
# 4    Stats          10.0%       5.754            0.9918   0.3445                  -65.26%  *Target not reached
# 5      Raw          10.0%     461.177            0.6817   0.1629                  -76.11%
# 6       DM          20.0%       2.633            0.9916   0.4650                  -53.11%  *Target not reached
# 7    Stats          20.0%       5.754            0.9918   0.3445                  -65.26%  *Target not reached
# 8      Raw          20.0%    1000.000            0.6817   0.1538                  -77.43%  *Target not reached
# Results for cw attack with mart training and eps=0.001:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       2.6329  0.464986      21.757644
# 1       DM       6.5819  0.318394      30.650757
# 2       DM      19.1194  0.152194      47.083600
# 3    Stats       5.7543  0.344538      22.389646
# 4    Stats      29.4873  0.068161      38.119542
# 5    Stats     362.6893  0.063492      45.740039
# 6      Raw       4.4241  0.229413       5.433538
# 7      Raw    1000.0000  0.153838      11.069438
# 8      Raw    1000.0000  0.153838      11.069438
# Warning: Target 3.0% is below the available range [14.2506%, 23.9439%]. Clamping to min.
# Breakpoint 3.0, Param for DM encoding: 2.6329
# Warning: Target 10.0% is below the available range [14.2506%, 23.9439%]. Clamping to min.
# Breakpoint 10.0, Param for DM encoding: 2.6329
# Breakpoint 20.0, Param for DM encoding: 11.8903
# Warning: Target 3.0% is below the available range [32.3436%, 49.8237%]. Clamping to min.
# Breakpoint 3.0, Param for Stats encoding: 5.7543
# Warning: Target 10.0% is below the available range [32.3436%, 49.8237%]. Clamping to min.
# Breakpoint 10.0, Param for Stats encoding: 5.7543
# Warning: Target 20.0% is below the available range [32.3436%, 49.8237%]. Clamping to min.
# Breakpoint 20.0, Param for Stats encoding: 5.7543
# Breakpoint 3.0, Param for Raw encoding: 989.3286
# Warning: Target 10.0% is above the available range [0.2551%, 3.0147%]. Clamping to max.
# Breakpoint 10.0, Param for Raw encoding: 1000.0000
# Warning: Target 20.0% is above the available range [0.2551%, 3.0147%]. Clamping to max.
# Breakpoint 20.0, Param for Raw encoding: 1000.0000
# Warning: Target 3.0% is below the available range [14.2506%, 23.9439%]. Clamping to min.
# Warning: Target 3.0% is below the available range [32.3436%, 49.8237%]. Clamping to min.
# Warning: Target 10.0% is below the available range [14.2506%, 23.9439%]. Clamping to min.
# Warning: Target 10.0% is below the available range [32.3436%, 49.8237%]. Clamping to min.
# Warning: Target 10.0% is above the available range [0.2551%, 3.0147%]. Clamping to max.
# Warning: Target 20.0% is below the available range [32.3436%, 49.8237%]. Clamping to min.
# Warning: Target 20.0% is above the available range [0.2551%, 3.0147%]. Clamping to max.
#
# ================================================================================
# SUMMARY TABLE FOR CW ATTACK (mart/eps0.01)
# ================================================================================
#   Encoding % Change in L2 C Parameter Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%       2.633            0.9916   0.6359                  -35.88%  *Target not reached
# 1    Stats           3.0%       5.754            0.9918   0.1289                  -87.01%  *Target not reached
# 2      Raw           3.0%     989.329            0.6817   0.5678                  -16.70%
# 3       DM          10.0%       2.633            0.9916   0.6359                  -35.88%  *Target not reached
# 4    Stats          10.0%       5.754            0.9918   0.1289                  -87.01%  *Target not reached
# 5      Raw          10.0%    1000.000            0.6817   0.5677                  -16.72%  *Target not reached
# 6       DM          20.0%      11.890            0.9916   0.5701                  -42.51%
# 7    Stats          20.0%       5.754            0.9918   0.1289                  -87.01%  *Target not reached
# 8      Raw          20.0%    1000.000            0.6817   0.5677                  -16.72%  *Target not reached
# Results for cw attack with mart training and eps=0.01:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       2.6329  0.635854      14.250634
# 1       DM       6.5819  0.626517      15.984831
# 2       DM      19.1194  0.528478      23.943907
# 3    Stats       5.7543  0.128852      32.343600
# 4    Stats      29.4873  0.046685      39.958045
# 5    Stats     362.6893  0.047619      49.823743
# 6      Raw       4.4241  0.617932       0.255131
# 7      Raw    1000.0000  0.567727       3.014699
# 8      Raw    1000.0000  0.567727       3.014699
# Warning: Target 3.0% is below the available range [19.5786%, 25.1637%]. Clamping to min.
# Breakpoint 3.0, Param for DM encoding: 2.6329
# Warning: Target 10.0% is below the available range [19.5786%, 25.1637%]. Clamping to min.
# Breakpoint 10.0, Param for DM encoding: 2.6329
# Breakpoint 20.0, Param for DM encoding: 4.6886
# Warning: Target 3.0% is below the available range [15.2148%, 52.4010%]. Clamping to min.
# Breakpoint 3.0, Param for Stats encoding: 5.7543
# Warning: Target 10.0% is below the available range [15.2148%, 52.4010%]. Clamping to min.
# Breakpoint 10.0, Param for Stats encoding: 5.7543
# Breakpoint 20.0, Param for Stats encoding: 9.1895
# Warning: Target 3.0% is above the available range [0.0000%, 0.0000%]. Clamping to max.
# Breakpoint 3.0, Param for Raw encoding: 4.4241
# Warning: Target 10.0% is above the available range [0.0000%, 0.0000%]. Clamping to max.
# Breakpoint 10.0, Param for Raw encoding: 4.4241
# Warning: Target 20.0% is above the available range [0.0000%, 0.0000%]. Clamping to max.
# Breakpoint 20.0, Param for Raw encoding: 4.4241
# Warning: Target 3.0% is below the available range [19.5786%, 25.1637%]. Clamping to min.
# Warning: Target 3.0% is below the available range [15.2148%, 52.4010%]. Clamping to min.
# Warning: Target 3.0% is above the available range [0.0000%, 0.0000%]. Clamping to max.
# Warning: Target 10.0% is below the available range [19.5786%, 25.1637%]. Clamping to min.
# Warning: Target 10.0% is below the available range [15.2148%, 52.4010%]. Clamping to min.
# Warning: Target 10.0% is above the available range [0.0000%, 0.0000%]. Clamping to max.
# Warning: Target 20.0% is above the available range [0.0000%, 0.0000%]. Clamping to max.
#
# ================================================================================
# SUMMARY TABLE FOR CW ATTACK (mart/eps0.1)
# ================================================================================
#   Encoding % Change in L2 C Parameter Baseline Accuracy Accuracy Decrease in Accuracy (%)                Notes
# 0       DM           3.0%       2.633            0.9916   0.6256                  -36.91%  *Target not reached
# 1    Stats           3.0%       5.754            0.9918   0.6060                  -38.90%  *Target not reached
# 2      Raw           3.0%       4.424            0.6817   0.6258                   -8.20%  *Target not reached
# 3       DM          10.0%       2.633            0.9916   0.6256                  -36.91%  *Target not reached
# 4    Stats          10.0%       5.754            0.9918   0.6060                  -38.90%  *Target not reached
# 5      Raw          10.0%       4.424            0.6817   0.6258                   -8.20%  *Target not reached
# 6       DM          20.0%       4.689            0.9916   0.6215                  -37.33%
# 7    Stats          20.0%       9.190            0.9918   0.4100                  -58.66%
# 8      Raw          20.0%       4.424            0.6817   0.6258                   -8.20%  *Target not reached
# Results for cw attack with mart training and eps=0.1:
#   encoding  param_value  accuracy  pct_change_l2
# 0       DM       2.6329  0.625584   1.957860e+01
# 1       DM       6.5819  0.619048   2.025191e+01
# 2       DM      19.1194  0.569561   2.516371e+01
# 3    Stats       5.7543  0.605976   1.521479e+01
# 4    Stats      29.4873  0.154995   3.952092e+01
# 5    Stats     362.6893  0.131653   5.240100e+01
# 6      Raw       4.4241  0.625779   6.133519e-07
# 7      Raw    1000.0000  0.625779   6.133519e-07
# 8      Raw    1000.0000  0.625779   6.133519e-07
